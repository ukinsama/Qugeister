# %% [markdown]
# # 環境構築チュートリアル
# このノートブックでは、**量子層統合型不完全情報ゲームAI** プロジェクトを実行するための環境構築と初期動作確認を行います。
# - 推奨環境：Python 3.10+, CUDA対応GPU（任意）
# - 主なライブラリ：PyTorch, PennyLane, Qiskit, Graphviz

# %%
# !python --version
# !pip list | grep torch || true
# !pip list | grep pennylane || true
# Out:
# Python 3.11.13
# torch                      2.7.0
# torchaudio                 2.7.1
# torchvision                0.22.0
# torchvision-extra-decoders 0.0.2

# %% [markdown]
# ## 依存ライブラリのインストール

# %%
# !pip install torch torchvision
# !pip install pennylane qiskit graphviz tqdm matplotlib seaborn
# Out:
# Requirement already satisfied: torch in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (2.7.0)
# Requirement already satisfied: torchvision in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (0.22.0)
# Requirement already satisfied: filelock in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from torch) (4.14.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from torch) (2025.5.1)
# Requirement already satisfied: numpy in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from torchvision) (1.24.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from torchvision) (11.2.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: pennylane in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (0.37.0)
# Requirement already satisfied: qiskit in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (1.3.1)
# Requirement already satisfied: graphviz in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (0.21)
# Requirement already satisfied: tqdm in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (4.67.1)
# Requirement already satisfied: matplotlib in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (3.10.3)
# Requirement already satisfied: seaborn in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy<2.0 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from pennylane) (1.24.4)
# Requirement already satisfied: scipy in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from pennylane) (1.15.2)
# Requirement already satisfied: networkx in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from pennylane) (3.4.2)
# Requirement already satisfied: rustworkx in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from pennylane) (0.16.0)
# Requirement already satisfied: autograd in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from pennylane) (1.6.2)
# Requirement already satisfied: toml in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from pennylane) (0.10.2)
# Requirement already satisfied: appdirs in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from pennylane) (1.4.4)
# Requirement already satisfied: semantic-version>=2.7 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from pennylane) (2.10.0)
# Requirement already satisfied: autoray>=0.6.11 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from pennylane) (0.7.0)
# Requirement already satisfied: cachetools in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from pennylane) (6.0.0)
# Requirement already satisfied: pennylane-lightning>=0.37 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from pennylane) (0.37.0)
# Requirement already satisfied: requests in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from pennylane) (2.32.4)
# Requirement already satisfied: typing-extensions in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from pennylane) (4.14.0)
# Requirement already satisfied: packaging in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from pennylane) (25.0)
# Requirement already satisfied: sympy>=1.3 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from qiskit) (1.14.0)
# Requirement already satisfied: dill>=0.3 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from qiskit) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from qiskit) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from qiskit) (5.4.1)
# Requirement already satisfied: symengine<0.14,>=0.11 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from qiskit) (0.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: pandas>=1.2 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from seaborn) (2.3.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from python-dateutil>=2.8.0->qiskit) (1.17.0)
# Requirement already satisfied: pbr>=2.0.0 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from stevedore>=3.0.0->qiskit) (6.1.1)
# Requirement already satisfied: setuptools in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit) (75.8.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from sympy>=1.3->qiskit) (1.3.0)
# Requirement already satisfied: future>=0.15.2 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from autograd->pennylane) (1.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from requests->pennylane) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from requests->pennylane) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from requests->pennylane) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sotokawakishou/miniforge3/envs/quantum-arm/lib/python3.11/site-packages (from requests->pennylane) (2025.6.15)

# %% [markdown]
# ## CUDA動作確認（フォールバックメッセージ付き）

# %%
import torch

if torch.cuda.is_available():
    print("CUDA available: True")
    print("Device Name:", torch.cuda.get_device_name(0))
else:
    print("CUDA available: False")
    print("⚠ CUDAが無効なため、CPU（default.qubit）での実行にフォールバックします。")
# Out:
# CUDA available: False
# ⚠ CUDAが無効なため、CPU（default.qubit）での実行にフォールバックします。

# %% [markdown]
# ## PennyLaneデバイス動作確認

# %%
import pennylane as qml

dev = qml.device("default.qubit", wires=2)

@qml.qnode(dev)
def circuit():
    qml.Hadamard(0)
    qml.CNOT([0, 1])
    return qml.state()

print("Sample QNN output:", circuit())
# Out:
# Sample QNN output: [0.70710678+0.j 0.        +0.j 0.        +0.j 0.70710678+0.j]

# %% [markdown]
# ## GeisterGame の動作確認

# %%
from geister_game import GeisterGame

game = GeisterGame()
game.display_board(reveal_opponent_pieces=True)
# Out:
#   0 1 2 3 4 5
# 0  . G B B B .
# 1  . G G B G .
# 2  . . . . . .
# 3  . . . . . .
# 4  . B B B G .
# 5  . B G G G .
# ---------------

# %% [markdown]
# ## 簡易学習テスト

# %%
from train import run_geister_cqcnn_training

# エピソード数を少なくしてテスト実行
run_geister_cqcnn_training(episodes=5)
# Out:
# --- Training CQCNN Agent (Qubits: 4, CNN->QNN Feat: 4) ---
# Initialized QNN device: lightning.qubit with 4 qubits.
# Training finished.
#
# --- Evaluating Trained CQCNN Agent A vs Random ---
# [{'episode': 1,
#   'wins_A': 0,
#   'wins_B': 1,
#   'draws': 0,
#   'epsilon_A': 0.4995102449183538,
#   'epsilon_B': 0.4995102449183538},
#  {'episode': 2,
#   'wins_A': 0,
#   'wins_B': 2,
#   'draws': 0,
#   'epsilon_A': 0.4990209793469932,
#   'epsilon_B': 0.4990209793469932},
#  {'episode': 3,
#   'wins_A': 1,
#   'wins_B': 2,
#   'draws': 0,
#   'epsilon_A': 0.4985322027966528,
#   'epsilon_B': 0.4985322027966528},
#  {'episode': 4,
#   'wins_A': 2,
#   'wins_B': 2,
#   'draws': 0,
#   'epsilon_A': 0.4980439147785558,
#   'epsilon_B': 0.4980439147785558},
#  {'episode': 5,
#   'wins_A': 3,
#   'wins_B': 2,
#   'draws': 0,
#   'epsilon_A': 0.49755611480441436,
#   'epsilon_B': 0.49755611480441436}]
